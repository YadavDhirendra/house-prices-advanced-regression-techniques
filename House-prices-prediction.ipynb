# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
df.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# Name: count, dtype: int64

# %%
# Function to replace nan value with mean or mode depending on feature type
no_of_rows = df.shape[0]
def ReplaceNan(DataFrame):
    column = DataFrame.columns
    for col in column:
        if DataFrame[col].isnull().sum() > (no_of_rows/2):
            DataFrame.drop([col],axis=1,inplace=True)
        if DataFrame[col].isnull().sum() > 0:
            if DataFrame.dtypes[col] == 'int64' or DataFrame.dtypes[col] == 'float64':
                DataFrame[col] = DataFrame[col].fillna(DataFrame[col].mean())
            else:
                DataFrame[col] = DataFrame[col].fillna(DataFrame[col].mode()[0])
    return DataFrame

# %%
clean_df = ReplaceNan(df)

# %%
sns.heatmap(clean_df.isnull(), yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1460, 76)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
test_df = pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
sns.heatmap(test_df.isnull(), yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
clean_test_df = ReplaceNan(test_df)
clean_test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
# 3  1464          60       RL         78.0     9978   Pave      IR1
# 4  1465         120       RL         43.0     5005   Pave      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         Lvl    AllPub    Inside  ...           0             0         0
# 1         Lvl    AllPub    Corner  ...          36             0         0
# 2         Lvl    AllPub    Inside  ...          34             0         0
# 3         Lvl    AllPub    Inside  ...          36             0         0
# 4         HLS    AllPub    Inside  ...          82             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
sns.heatmap(clean_test_df.isnull(), yticklabels=False,cbar=False,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Converting Categorical features into Binary features

# Function to create list of categorical columns
def CategoricalColumns(df):
    column = df.columns
    catCol = list(df.columns)
    for col in column:
        if df.dtypes[col] != 'object':
            catCol.remove(col)
    return catCol

# %%
clean_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
clean_df.dropna(inplace=True)
clean_df.shape
# Out:
# (1460, 76)

# %%
clean_test_df.to_csv('testformulated.csv',index=False)

# %%
clean_df.to_csv('trainformulated.csv',index=False)

# %%
clean_test_df.shape
# Out:
# (1459, 75)

# %%
clean_df.shape
# Out:
# (1460, 76)

# %%
df = clean_df

# %%
clean_df = df

# %%
clean_df = pd.concat([clean_df,clean_test_df],axis=0)

# %%
# removing saleprice as it will not be counted as categorical variable
# clean_df.drop(['SalePrice'],axis=1)
clean_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1454         Lvl    AllPub    Inside  ...             0         0           0
# 1455         Lvl    AllPub    Inside  ...             0         0           0
# 1456         Lvl    AllPub    Inside  ...             0         0           0
# 1457         Lvl    AllPub    Inside  ...             0         0           0
# 1458         Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Function to create the dummies from categorical variables
def category_onehot_multcols(multcols,clean_df):
    df_final = clean_df
    i = 0
    for fields in multcols:
        
        df1 = pd.get_dummies(clean_df[fields],drop_first=True)
        clean_df.drop([fields],axis=1,inplace=True)
        
        if i==0:
            df_final = df1
        else:
            df_final = pd.concat([df_final,df1],axis=1)
        i=i+1
        
    clean_df = pd.concat([clean_df,df_final],axis=1)
    return clean_df

# %%
catCol = CategoricalColumns(clean_df)
catCol
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
clean_df = category_onehot_multcols(catCol,clean_df)

# %%
clean_df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  ConLI  ConLw  \
# ...

# %%
clean_df = clean_df.loc[:,~clean_df.columns.duplicated()]

# %%
clean_df.shape
# Out:
# (2919, 177)

# %%
df_train = clean_df.iloc[:1460,:]
df_test = clean_df.iloc[1460:,:]

# %%
df_train.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  ConLI  ConLw    New    Oth  \
# 0          2003       196.0       706.0  ...  False  False  False  False
# 1          1976         0.0       978.0  ...  False  False  False  False
# 2          2002       162.0       486.0  ...  False  False  False  False
# 3          1970         0.0       216.0  ...  False  False  False  False
# 4          2000       350.0       655.0  ...  False  False  False  False
#
#      WD  AdjLand  Alloca  Family  Normal  Partial
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  ConLI  ConLw    New  \
# 0       1961          1961         0.0       468.0  ...  False  False  False
# 1       1958          1958       108.0       923.0  ...  False  False  False
# 2       1997          1998         0.0       791.0  ...  False  False  False
# 3       1998          1998        20.0       602.0  ...  False  False  False
# 4       1992          1992         0.0       263.0  ...  False  False  False
#
#      Oth    WD  AdjLand  Alloca  Family  Normal  Partial
# ...

# %%
df_test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /var/folders/hy/6chg5q7d45g2wv57790cvv080000gn/T/ipykernel_94063/2787191513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.drop(['SalePrice'],axis=1,inplace=True)

# %%
df_test.shape
# Out:
# (1459, 176)

# %%
X_train = df_train.drop(['SalePrice'],axis=1)
y_train = df_train['SalePrice']

# %%
# !pip install xgboost

# %%
y_train.isnull().value_counts()
# Out:
# SalePrice
# False    1460
# Name: count, dtype: int64

# %%
import xgboost
classifier = xgboost.XGBRegressor()
classifier.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
import pickle
filename = 'finalized_model.pkl'
pickle.dump(classifier, open(filename,'wb'))

# %%
y_pred = classifier.predict(df_test)

# %%
y_pred
# Out:
# array([118869.64, 155126.55, 197063.77, ..., 153198.12, 117167.49,
#        203801.14], dtype=float32)

# %%
## create sample submission file and submit
pred = pd.DataFrame(y_pred)
sub_pd = pd.read_csv('sample_submission.csv')
datasets = pd.concat([sub_pd['Id'],pred],axis=1)
datasets.columns = ['Id','SalePrice']
datasets.to_csv('final_submission.csv',index=False)
